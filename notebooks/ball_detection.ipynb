# %%
# !unzip ball_dataset.zip
# Out:
#   inflating: ball_dataset/train/images/00037_00002_jpg.rf.fdda79381bd3426881ea0225beb876fd.jpg
#   inflating: __MACOSX/ball_dataset/train/images/._00037_00002_jpg.rf.fdda79381bd3426881ea0225beb876fd.jpg
#   inflating: ball_dataset/train/images/10_011_jpg.rf.90ab1238399bba7214b9edc310fedcb0.jpg
#   inflating: __MACOSX/ball_dataset/train/images/._10_011_jpg.rf.90ab1238399bba7214b9edc310fedcb0.jpg
#   inflating: ball_dataset/train/images/00064_00006_jpg.rf.dbf48cfa814fa995ccb225b30f705d8f.jpg
#   inflating: __MACOSX/ball_dataset/train/images/._00064_00006_jpg.rf.dbf48cfa814fa995ccb225b30f705d8f.jpg
#   inflating: ball_dataset/train/images/05_023_jpg.rf.b96e07a34fdd53628ffcee7be23109f5.jpg
#   inflating: __MACOSX/ball_dataset/train/images/._05_023_jpg.rf.b96e07a34fdd53628ffcee7be23109f5.jpg
#   inflating: ball_dataset/train/images/b2ac3266-3a40-4003-b6d1-a3fe869a761c_frame_44.jpg
#   inflating: ball_dataset/train/images/Golf17_044_00007_jpg.rf.3b9156d225a749e68f2ac47befd1da75.jpg
# ...

# %%
#!g1.1
# !pwd

# %%
#!g1.1
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data='ball_dataset/data.yaml', epochs=50, imgsz=640, batch=-1)
# Out:
# Ultralytics YOLOv8.0.163 🚀 Python-3.8.12 torch-1.9.1+cu111 CUDA:0 (Tesla V100-PCIE-32GB, 32501MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
#!g1.1
# %pip install ultralytics -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -rotobuf (/home/jupyter/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution - (/home/jupyter/.local/lib/python3.8/site-packages)
# ...
# WARNING: Ignoring invalid distribution -rotobuf (/home/jupyter/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution - (/home/jupyter/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/home/jupyter/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution - (/home/jupyter/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/home/jupyter/.local/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution - (/home/jupyter/.local/lib/python3.8/site-packages)
# WARNING: You are using pip version 21.3.1; however, version 23.2.1 is available.
# ...

# %%
#!g1.1
from ultralytics import YOLO

# Load a model
model = YOLO('runs/detect/train3/weights/best.pt')  # load a pretrained model (recommended for training)

# %%
#!g1.1
# Train the model
results = model.train(data='ball_dataset/data.yaml', epochs=50, imgsz=640, batch=-1, lr0=1e-5)
# Out:
# Ultralytics YOLOv8.0.163 🚀 Python-3.8.12 torch-1.9.1+cu111 CUDA:0 (Tesla V100-PCIE-32GB, 32501MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
#!g1.1

# %%
#!g1.1

# %%
#!g1.1
model.predict('positions_of_the_golf_swing_train/1934fd93-8315-401d-a534-71b4dfef602f.mp4', save=True)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/74) /home/jupyter/work/resources/golf/positions_of_the_golf_swing_train/1934fd93-8315-401d-a534-71b4dfef602f.mp4: 640x384 (no detections), 14.2ms
# video 1/1 (2/74) /home/jupyter/work/resources/golf/positions_of_the_golf_swing_train/1934fd93-8315-401d-a534-71b4dfef602f.mp4: 640x384 (no detections), 20.7ms
# ...

# %%
#!g1.1

# %%
#!g1.1

# %%
#!g1.1

# %%
#!g1.1
